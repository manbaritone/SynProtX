# %%
import pandas as pd
from constants import *

# %%
GeneExp = pd.read_csv(f"{EXPORT_DATA_PATH}/CCLE_expression_cleaned.csv", index_col=0)

# %%
# for changing annotation name -> ACH
sample_info = pd.read_csv(f"{RAW_DATA_PATH}/sample_info.csv")

# %% [markdown]
# ## Load and clean proteomics

# %%
proteomics_df = pd.read_csv(f"{RAW_DATA_PATH}/1-s2.0-S1535610822002744-mmc3.csv")

# %%
proteomics_df
# Out:
#      Project_Identifier  P37108;SRP14_HUMAN  Q96JP5;ZFP91_HUMAN  \
# 0        SIDM00018;K052             7.10955             3.41494
# 1       SIDM00023;TE-12             6.82802             4.14346
# 2       SIDM00040;TMK-1             7.01426             4.19987
# 3    SIDM00041;STS-0421             5.28591             3.35789
# 4         SIDM00042;PL4             5.70786                 NaN
# ..                  ...                 ...                 ...
# 944  SIDM01248;CGTH-W-1             6.31631             4.86933
# 945        SIDM01251;H9             6.23087             2.71686
# 946     SIDM01259;GR-ST             7.00407                 NaN
# 947   SIDM01261;YMB-1-E             6.76532             3.75777
# 948      SIDM01265;MM1S             6.91982             3.70284
#
#      Q9Y4H2;IRS2_HUMAN  P36578;RL4_HUMAN  Q6SPF0;SAMD1_HUMAN  \
# 0                  NaN           7.86661             3.89547
# 1              2.23781           7.62878             3.19811
# ...

# %%
col = proteomics_df.columns
sum("_HUMAN" in x for x in col)
# Out:
# 6692

# %%
Project_Identifier = [x.split(";")[1] for x in proteomics_df["Project_Identifier"]]
proteomics_df["Project_Identifier"] = Project_Identifier
proteomics_df
# Out:
#     Project_Identifier  P37108;SRP14_HUMAN  Q96JP5;ZFP91_HUMAN  \
# 0                 K052             7.10955             3.41494
# 1                TE-12             6.82802             4.14346
# 2                TMK-1             7.01426             4.19987
# 3             STS-0421             5.28591             3.35789
# 4                  PL4             5.70786                 NaN
# ..                 ...                 ...                 ...
# 944           CGTH-W-1             6.31631             4.86933
# 945                 H9             6.23087             2.71686
# 946              GR-ST             7.00407                 NaN
# 947            YMB-1-E             6.76532             3.75777
# 948               MM1S             6.91982             3.70284
#
#      Q9Y4H2;IRS2_HUMAN  P36578;RL4_HUMAN  Q6SPF0;SAMD1_HUMAN  \
# 0                  NaN           7.86661             3.89547
# 1              2.23781           7.62878             3.19811
# ...

# %%
proteomics_df.to_csv(f"{EXPORT_DATA_PATH}/protein_omics_data_cleaned.csv")
